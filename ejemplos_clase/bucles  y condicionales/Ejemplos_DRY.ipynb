# %%
tipo_dato = "int"

n1_str = input("Introduce el n1: ")
n2_str = input("Introduce el n2: ")
if tipo_dato == "int":
    n1 = int(n1_str)
    n2 = int(n2_str)
else:
    if tipo_dato == "float":
       
        n1 = float(n1_str)
        n2 = float(n2_str)
    else:
        if tipo_dato == "complex":
           
            n1 = complex(n1_str)
            n2 = complex(n2_str)

# %%
op = 1
n1 = 2
n2 = 3
 
if op == 1:
    resultado = n1 + n2
    simbolo = "+"
    
    
else:
    if op == 2:
        resultado = n1 - n2
        simbolo = "-"

# %%
# numero_str = input("Introduce un numero: ")
# numero = int(numero_str)
numero = 1
limite_superior = 11
limite_numeros = 2


while numero < limite_numeros:
    print("="*40)
    print("Tabla de multiplicar del número: ", numero)
    print("="*40)
    
    contador = 0
    while contador < limite_superior:
        
        producto = numero * contador

        print(numero, "X", contador, "=", producto)
        contador = contador + 1
        #contador += 1 tambien se puede así
    
    print("*"* 40)
    
    
    numero = numero + 1
# Out:
# ...
# Tabla de multiplicar del número:  1
# ...
# 1 X 0 = 0
# 1 X 1 = 1
# 1 X 2 = 2
# 1 X 3 = 3
# 1 X 4 = 4
# 1 X 5 = 5
# 1 X 6 = 6
# 1 X 7 = 7
# 1 X 8 = 8
# 1 X 9 = 9
# 1 X 10 = 10
# ****************************************

# %%
menu = """ 
1. Multiplicar
2. Sumatorio
3. Factorial
4. Salir"""

LIMITE_SUPERIOR = 10



op = 0
while op != 4:
    print(menu)
    op_str = input("Introduce una op: ")
    op = int(op_str)
    while op < 1 or op > 4:
        op_str = input("Introduce una op: ")
        op = int(op_str)
    if op != 4:
        numero_str = input("Introduce número: ")
        numero = int(numero_str)
            
        if op == 1:
            contador = 0
            
            
            print("="*40)
            print("Tabla de multiplicar del número: ", numero)
            print("="*40)
            while contador < LIMITE_SUPERIOR:
                producto = numero * contador
                print(numero, "X", contador, "=", producto)
                contador = contador + 1
            
            
            
        elif op == 2:
            
            sumatorio = 0
            contador = 1
            while contador <= numero:
                sumatorio += contador
                contador += 1
            print("El sumatorio del número es: ", sumatorio)
            
            
            
        elif op == 3:
            print("Vamos a hacer factorial")
            factorial = 1
            contador = 1
            
            while contador <= numero:
                factorial *= contador
                #factorial = factorial * contador
                
                contador += 1
                
            print("El factorial del número es: ", factorial)
# Out:
#
# 1. Multiplicar
# 2. Sumatorio
# 3. Factorial
# 4. Salir
# ...
# Tabla de multiplicar del número:  5
# ...
# 5 X 0 = 0
# 5 X 1 = 5
# 5 X 2 = 10
# 5 X 3 = 15
# 5 X 4 = 20
# 5 X 5 = 25
# 5 X 6 = 30
# 5 X 7 = 35
# 5 X 8 = 40
# 5 X 9 = 45
#
# 1. Multiplicar
# 2. Sumatorio
# 3. Factorial
# 4. Salir

# %%
op_str = input("Introduce una op: ")
op = int(op_str)

while op < 1 or op > 4:
    print("La opción no es válida")
    op_str = input("Introduce una op: ")
    op = int(op_str)
    
print(op)
# Out:
# La opción no es válida
# La opción no es válida
# La opción no es válida
# 3

# %%
saldo_inicial = 1000

menu = """
1. Sacar dinero
2. Ingresar dinero
3. Mostrar dinero
4. Salir"""

CANTIDAD_MAXIMA_INGRESAR = 10000









op_int = 0
while op_int != 4:
    
    op_str = input("Introduce op: ")
    op_int = int(op_str)
    #Lo validas que sabess
    
    if op_int == 1:
        saldo_retirar_str = input("Introduce el saldo a retirar: ")
        saldo_retirar_int = int(saldo_retirar_str)
        
        
        while saldo_retirar_int > saldo_inicial:
            print("No tienes suficiente dinero")
            saldo_retirar_str = input("Introduce el saldo a retirar: ")
            saldo_retirar_int = int(saldo_retirar_str)
            
        saldo_inicial = saldo_inicial - saldo_retirar_int
        print("Has retirado", saldo_retirar_int, "y te queda: ", saldo_inicial)
        #saldo_inicial -= saldo_retirar
    elif op_int == 2:
        saldo_ingresar = int(input("Introduce el saldo a ingresar: "))
        while saldo_ingresar < 0 or saldo_ingresar > CANTIDAD_MAXIMA_INGRESAR:
            print("Error el saldo no es válido: ")
            saldo_ingresar = int(input("Introduce el saldo a ingresar: "))
        
        saldo_inicial += saldo_ingresar
        
        print("Has ingresado", saldo_ingresar, " y te  quedan: ", saldo_inicial)
    elif op_int == 3:
        print("[*] Has elegido mostrar saldo! Vamos a calcular cuánto dinero tienes [*]")
        print("Tienes un total de: ", saldo_inicial)
        
            
        
        
        
        
        
print("El programa se ha terminado")
# Out:
# [*] Has elegido mostrar saldo! Vamos a calcular cuánto dinero tienes [*]
# Tienes un total de:  1000
# El programa se ha terminado

# %%
#Ahora mismo  el programa, cuando sale del while me dice que la autenticación está completa
# No obstante, no tenemos manera de saber si ha sido correcta o no. Propongo
# Que implementes esta funcionalidad y además, unifiques este código con el de arriba. 



usuario = "lfnovales"
passwd = "IMAT2026"


usuario_login = input("Introduce el usuario: ")
passwd_login = input("Introduce tu passwd: ")
INTENTOS_MAX = 3


contador_intentos = 0
while (usuario_login != usuario or passwd_login != passwd) and contador_intentos < INTENTOS_MAX :
    print("El login no ha sido satisfactorio")
    usuario_login = input("Introduce el usuario: ")
    passwd_login = input("Introduce tu passwd: ")
    contador_intentos += 1
    
    


print("Autenticación completada!")
# Out:
# El login no ha sido satisfactorio
# El login no ha sido satisfactorio
# El login no ha sido satisfactorio
# Autenticación completada!
